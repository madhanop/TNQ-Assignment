# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
# Out:
# C:\Users\Home\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df =pd.read_csv(r"C:\Users\Home\Downloads\world_population\world_population.csv")

# %%
df.head()
# Out:
#    Rank CCA3         Country           Capital Continent  2022 Population  \
# 0    36  AFG     Afghanistan             Kabul      Asia         41128771
# 1   138  ALB         Albania            Tirana    Europe          2842321
# 2    34  DZA         Algeria           Algiers    Africa         44903225
# 3   213  ASM  American Samoa         Pago Pago   Oceania            44273
# 4   203  AND         Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.shape
# Out:
# (234, 17)

# %% [markdown]
# # Exploratory data analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<AxesSubplot:title={'center':'Rank'}>,
#         <AxesSubplot:title={'center':'2022 Population'}>,
#         <AxesSubplot:title={'center':'2020 Population'}>,
#         <AxesSubplot:title={'center':'2015 Population'}>],
#        [<AxesSubplot:title={'center':'2010 Population'}>,
#         <AxesSubplot:title={'center':'2000 Population'}>,
#         <AxesSubplot:title={'center':'1990 Population'}>,
#         <AxesSubplot:title={'center':'1980 Population'}>],
#        [<AxesSubplot:title={'center':'1970 Population'}>,
#         <AxesSubplot:title={'center':'Area (km²)'}>,
#         <AxesSubplot:title={'center':'Density (per km²)'}>,
#         <AxesSubplot:title={'center':'Growth Rate'}>],
#        [<AxesSubplot:title={'center':'World Population Percentage'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
sns.boxplot(x="2022 Population", y="2020 Population", data = df)
# Out:
# <AxesSubplot:xlabel='2022 Population', ylabel='2020 Population'>

# %%
sns.boxplot(x="2010 Population", data = df)
# Out:
# <AxesSubplot:xlabel='2010 Population'>

# %%
Obj_Col = df.columns[1:5]
Obj_Col
# Out:
# Index(['CCA3', 'Country', 'Capital', 'Continent'], dtype='object')

# %%
Continous_Col=df.columns[5:]
Continous_Col
# Out:
# Index(['2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
for i in Object_Col:
    for j in df[i]:
        if(j.isalpha() or " " in j):
            continue
        else:
            print("There is a Special Character in",i,"The Values is ",j)
# Out:
# There is a Special Character in Country The Values is  Guinea-Bissau
# There is a Special Character in Country The Values is  Timor-Leste
# There is a Special Character in Capital The Values is  Porto-Novo
# There is a Special Character in Capital The Values is  N'Djamena
# There is a Special Character in Capital The Values is  Basse-Terre
# There is a Special Character in Capital The Values is  Port-au-Prince
# There is a Special Character in Capital The Values is  Fort-de-France
# There is a Special Character in Capital The Values is  Saint-Denis
# There is a Special Character in Capital The Values is  Saint-Pierre
# There is a Special Character in Capital The Values is  Nuku‘alofa
# There is a Special Character in Capital The Values is  Port-of-Spain
# There is a Special Character in Capital The Values is  Port-Vila
# There is a Special Character in Capital The Values is  Mata-Utu

# %% [markdown]
# # Visualization

# %%
sns.countplot(x="2000 Population", hue = "Growth Rate", data = df)
# Out:
# <AxesSubplot:xlabel='2000 Population', ylabel='count'>

# %%
sns.pairplot(df)

# %%
plt.scatter(df['World Population Percentage'],df['2020 Population'])

# %%
plt.scatter(df['World Population Percentage'],df['2022 Population'])

# %%
plt.scatter(df['World Population Percentage'],df['1980 Population'])

# %%
plt.scatter(df['World Population Percentage'],df['1970 Population'])

# %%
plt.scatter(df['2015 Population'],df['World Population Percentage'])

# %%
plt.scatter(df['Growth Rate'],df['World Population Percentage'])

# %%
plt.scatter(df['Country'],df['World Population Percentage'])

# %%
sorted_df = df.sort_values(by=["Rank"])

# %%
sorted_df.drop(['Rank','CCA3','Capital','Country'],axis=1,inplace=True)

# %%
sorted_df
# Out:
#          Continent  2022 Population  2020 Population  2015 Population  \
# 41            Asia       1425887337       1424929781       1393715448
# 92            Asia       1417173173       1396387127       1322866505
# 221  North America        338289857        335942003        324607776
# 93            Asia        275501339        271857970        259091970
# 156           Asia        235824862        227196741        210969298
# ..             ...              ...              ...              ...
# 137  North America             4390             4500             5059
# 64   South America             3780             3747             3408
# 150        Oceania             1934             1942             1847
# 209        Oceania             1871             1827             1454
# 226         Europe              510              520              564
#
#      2010 Population  2000 Population  1990 Population  1980 Population  \
# ...

# %%
sorted_df.Continent = LabelEncoder().fit_transform(sorted_df.Continent)

# %%
def correlation(dataset, threshold):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > threshold:
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
x =df.drop('World Population Percentage',axis=1)
y =df['World Population Percentage']

# %%
correlation(x,0.9)
# Out:
# {'1970 Population',
#  '1980 Population',
#  '1990 Population',
#  '2000 Population',
#  '2010 Population',
#  '2015 Population',
#  '2020 Population'}

# %%
corr= df.corr()
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>
